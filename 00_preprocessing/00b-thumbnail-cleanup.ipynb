# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("cleanup_thumb.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                    id  \
# 0           7  MTM3Mjk5LTgzMjE2MDIyX3R3ZWV0XzE3NDgz
# 1          16  MTM3MzI2LTgzMTQ4MDI3X3R3ZWV0XzE3NDgz
# 2         242  MTM3MzI5LTgzMDAxNzA1X3R3ZWV0XzE3NDgz
# 3         247       MTM3MzI5LTgyOTcxMzI0X3R3ZWV0XzA
# 4         252       MTM3MzI2LTgyOTQ5NTY0X3R3ZWV0XzA
#
#                                            image_url
# 0  https://media.allure.com/photos/5a0ca6ff949532...
# 1  https://assets.vogue.com/photos/5a0b1d2aa29362...
# 2  https://media.wmagazine.com/photos/5a03e76c931...
# 3  https://media.wmagazine.com/photos/59f8f095dc2...
# 4  https://assets.vogue.com/photos/5891eb6223f988...

# %%
import boto
import boto3
conn = boto.connect_s3()
import requests

# %%
# Uses the creds in ~/.aws/credentials
s3 = boto3.resource('s3')
bucket_name_to_upload_image_to = 'thumbcleanup'

# %%
# Do this as a quick and easy check to make sure your S3 access is OK
for bucket in s3.buckets.all():
    if bucket.name == bucket_name_to_upload_image_to:
        print('Good to go. Found the bucket to upload the image into.')
        good_to_go = True

if not good_to_go:
    print('Not seeing your s3 bucket, might want to double check permissions in IAM')
# Out:
# Good to go. Found the bucket to upload the image into.

# %%
mapping_dict ={}
for i, img_url in enumerate(df["image_url"]):
    img_name = "thumbcleanup_%05d" % (i,)
    mapping_dict[img_name] = img_url
    
    if (img_url == np.nan) | (str(img_url) == "nan"):
        continue
    else:
        # Uses the creds in ~/.aws/credentials
        s3_image_filename = img_name
        internet_image_url = img_url

        # Given an Internet-accessible URL, download the image and upload it to S3,
        # without needing to persist the image to disk locally
        req_for_image = requests.get(internet_image_url, stream=True)
        file_object_from_req = req_for_image.raw
        req_data = file_object_from_req.read()

        # Do the actual upload to s3
        s3.Bucket(bucket_name_to_upload_image_to).put_object(Key=s3_image_filename, Body=req_data)

# %%
md_01 = pd.DataFrame(mapping_dict, index = range(0,len(mapping_dict)))
md_02 = pd.DataFrame(md_01.T[0])
pd.DataFrame(md_02).to_csv('../assets/thumbnail_cleanup.csv', index = range(0,len(mapping_dict)))

# %%
bucket_name = 'thumbcleanup'
s3 = boto3.resource('s3')
bucket = s3.Bucket(bucket_name)
images = [img.key for img in bucket.objects.all()]
client = boto3.client('rekognition')

results_wide = []
results_long = []

for img in images:
    img_dict_wide = {'img': img}
    #print(img)
    try:
        labels = client.detect_labels(Image={'S3Object':{'Bucket':bucket_name,'Name':img}},MinConfidence=75)
        if 'Labels' in labels:
            for l, label in enumerate(labels['Labels']):
                results_long.append({'img': img, 'type': 'Label', 'label': label['Name'], 
                                     'confidence': label['Confidence']})
                col = 'label_' + str(l)
                img_dict_wide[col] = label['Name']
                img_dict_wide[col + '_confidence'] = label['Confidence'] 
    except:
        continue
    try:        
        celebrities = client.recognize_celebrities(Image={'S3Object':{'Bucket':bucket_name,'Name':img}})
        if 'CelebrityFaces' in celebrities:
            for f, face in enumerate(celebrities['CelebrityFaces']):
                results_long.append({'img': img, 'type': 'Celebrity', 'label': face['Name'], 
                                     'confidence': face['Face']['Confidence']})
                col = 'celeb_' + str(f)
                img_dict_wide[col] = face['Name']
                img_dict_wide[col + '_confidence'] = face['Face']['Confidence']
    except:
        continue
    try:
        text_in_image = client.detect_text(Image={'S3Object':{'Bucket':bucket_name,'Name':img}})
        if "TextDetections" in text_in_image:
            for w, word in enumerate(text_in_image["TextDetections"]):
                results_long.append({'img': img, 'type': "Text", 'label': word["DetectedText"],
                                    'confidence': word["Confidence"]})
                col = 'word_' + str(w)
                img_dict_wide[col] = word["DetectedText"]
                img_dict_wide[col+ '_confidence'] = word["Confidence"]
    except:
        continue
            
    if 'Labels' not in labels and 'CelebrityFaces' not in celebrities and "TextDetections" not in text_in_image:
        results_long.append({'img': img, 'type': None, 'label': None, 'confidence': None})
        
    results_wide.append(img_dict_wide)
####
####
img_df_long = pd.DataFrame(results_long, columns=['img', 'type', 'label', 'confidence'])
img_df_wide = pd.DataFrame(results_wide)
cols = sorted(img_df_wide.columns)
cols.remove('img')
img_df_wide = img_df_wide[['img'] + cols]

# %%
md_01 = pd.DataFrame(mapping_dict, index = range(0,len(mapping_dict)))
md_02 = pd.DataFrame(md_01.T[0])
pd.DataFrame(md_02).to_csv('../assets/thumb_cleanup.csv', index = range(0,len(mapping_dict)))

# %%
img_df_long
# Out:
#                     img       type               label  confidence
# 0    thumbcleanup_00046      Label              Finger   95.046822
# 1    thumbcleanup_00046      Label                Hand   76.756683
# 2    thumbcleanup_00047      Label                Road   87.269890
# 3    thumbcleanup_00047       Text                  .y   47.015461
# 4    thumbcleanup_00047       Text                 ACE   85.307434
# 5    thumbcleanup_00047       Text                  .y   47.015461
# 6    thumbcleanup_00047       Text                 ACE   85.307434
# 7    thumbcleanup_00048      Label               Human   99.211685
# 8    thumbcleanup_00048      Label              People   99.211685
# 9    thumbcleanup_00048      Label              Person   99.211685
# 10   thumbcleanup_00048      Label              Female   77.129265
# 11   thumbcleanup_00048      Label                Girl   77.129265
# 12   thumbcleanup_00048      Label               Woman   77.129265
# 13   thumbcleanup_00049      Label               Human   98.769035
# 14   thumbcleanup_00049      Label              People   98.768997
# 15   thumbcleanup_00049      Label              Person   98.769035
# 16   thumbcleanup_00049  Celebrity        Prince Harry   99.992493
# 17   thumbcleanup_00050       Text                Aol.   81.026184
# 18   thumbcleanup_00050       Text       Log In wl our   79.213020
# 19   thumbcleanup_00050       Text          Aol a ount   77.897263
# 20   thumbcleanup_00050       Text                Aol.   81.026184
# 21   thumbcleanup_00050       Text                 our   94.138557
# 22   thumbcleanup_00050       Text                  wl   62.816666
# 23   thumbcleanup_00050       Text                  In   76.906265
# 24   thumbcleanup_00050       Text                 Log   82.990578
# 25   thumbcleanup_00050       Text                ount   95.567429
# 26   thumbcleanup_00050       Text                   a   56.421494
# 27   thumbcleanup_00050       Text                 Aol   81.702866
# 28   thumbcleanup_00051      Label               Human   99.085815
# 29   thumbcleanup_00051      Label              People   99.085800
# ..                  ...        ...                 ...         ...
# 273  thumbcleanup_00074      Label               Human   99.273262
# 274  thumbcleanup_00074      Label              People   99.273262
# 275  thumbcleanup_00074      Label              Person   99.273262
# 276  thumbcleanup_00074      Label              Blonde   99.201294
# 277  thumbcleanup_00074      Label              Female   99.201294
# 278  thumbcleanup_00074      Label                Girl   99.201294
# 279  thumbcleanup_00074      Label               Woman   99.201294
# 280  thumbcleanup_00074  Celebrity  Sam Taylor-Johnson   99.902512
# 281  thumbcleanup_00074  Celebrity         Naomi Watts   99.999962
# 282  thumbcleanup_00074       Text           GY Y TFLI   95.184944
# 283  thumbcleanup_00074       Text                   S   80.269226
# 284  thumbcleanup_00074       Text                  GY   98.976151
# 285  thumbcleanup_00074       Text                   Y   87.512032
# 286  thumbcleanup_00074       Text                TFLI   99.066673
# 287  thumbcleanup_00074       Text                   S   80.269226
# 288  thumbcleanup_00075      Label               Human   99.079681
# 289  thumbcleanup_00075      Label              People   99.079666
# 290  thumbcleanup_00075      Label              Person   99.079681
# 291  thumbcleanup_00075      Label              Female   87.356094
# 292  thumbcleanup_00075      Label                Girl   87.356094
# 293  thumbcleanup_00075      Label               Woman   87.356094
# 294  thumbcleanup_00075      Label                Face   84.361420
# 295  thumbcleanup_00075      Label            Portrait   84.361420
# 296  thumbcleanup_00075  Celebrity         Bella Hadid   99.971703
# 297  thumbcleanup_00076      Label               Human   99.084396
# 298  thumbcleanup_00076      Label              People   99.084389
# 299  thumbcleanup_00076      Label              Person   99.084396
# 300  thumbcleanup_00076      Label             Reading   93.670959
# 301  thumbcleanup_00076       Text                ACOR   74.753853
# 302  thumbcleanup_00076       Text                ACOR   74.753853
#
# [303 rows x 4 columns]

# %%
# for-loop to drop all "Human", "People", "Person" Label rows where the image 
# contains a celebrity.
for img in img_df_long["img"]:
    if len(img_df_long.loc[(img_df_long["img"] == img) & (img_df_long["type"]=="Celebrity")])>0:
        img_df_long = img_df_long.loc[~((img_df_long['img'] == img) 
                          & (img_df_long['label'].isin(['Human', 'People', 'Person'])))]

# %%
len(img_df_long)
# Out:
# 261

# %%
# for-loop to drop all "Label" rows below 90% confidence if there is a celebrity
for img in img_df_long["img"]:
    if len(img_df_long.loc[(img_df_long["img"] == img) & (img_df_long["type"]=="Celebrity")])>0:
        img_df_long = img_df_long.loc[~((img_df_long['img'] == img) 
                          & (img_df_long['type'].isin(['Label'])) & (img_df_long['confidence']<90))]

# %%
len(img_df_long)
# Out:
# 240

# %%
# for loop to drop all "Label", "Sticker", "Text" label rows where image contains text.
for img in img_df_long["img"]:
    if len(img_df_long.loc[(img_df_long["img"] == img) & (img_df_long["type"]=="Text")])>0:
        img_df_long = img_df_long.loc[~((img_df_long['img'] == img) 
                          & (img_df_long['label'].isin(['Label', 'Sticker', 'Text'])))]

# %%
len(img_df_long)
# Out:
# 240

# %%
media_new = []
for img in img_df_long['img'].unique():
    img_dict = {'img': img}
    if len(img_df_long[(img_df_long['img']==img) & (img_df_long['type']=='Label')])>0:
        img_dict['label'] = ' '.join(img_df_long.loc[(img_df_long['img']==img) & (img_df_long['type']=='Label'), 'label'].tolist())
    else:
        img_dict['label'] = None
    if len(img_df_long[(img_df_long['img']==img) & (img_df_long['type']=='Text')])>0:
        text = [str(detected_text) 
                for detected_text in img_df_long.loc[(img_df_long['img']==img) & (img_df_long['type']=='Text'), 'label'].tolist()]
        img_dict['text'] = ' '.join(text)
    else:
        img_dict['text'] = None
    img_dict['celebrity'] = len(img_df_long[(img_df_long['img']==img) & (img_df_long['type']=='Celebrity')])>0
    media_new.append(img_dict)
media_new_df = pd.DataFrame(media_new)

# %%
media_new_df
# Out:
#     celebrity                 img  \
# 0       False  thumbcleanup_00046
# 1       False  thumbcleanup_00047
# 2       False  thumbcleanup_00048
# 3        True  thumbcleanup_00049
# 4       False  thumbcleanup_00050
# 5        True  thumbcleanup_00051
# 6        True  thumbcleanup_00052
# 7       False  thumbcleanup_00053
# 8       False  thumbcleanup_00054
# 9        True  thumbcleanup_00055
# 10      False  thumbcleanup_00056
# 11      False  thumbcleanup_00057
# 12      False  thumbcleanup_00058
# 13       True  thumbcleanup_00059
# 14      False  thumbcleanup_00060
# 15       True  thumbcleanup_00061
# 16      False  thumbcleanup_00062
# 17       True  thumbcleanup_00063
# 18       True  thumbcleanup_00064
# 19       True  thumbcleanup_00066
# 20      False  thumbcleanup_00067
# 21       True  thumbcleanup_00068
# 22      False  thumbcleanup_00069
# 23      False  thumbcleanup_00070
# 24      False  thumbcleanup_00071
# 25       True  thumbcleanup_00072
# 26       True  thumbcleanup_00073
# 27       True  thumbcleanup_00074
# 28       True  thumbcleanup_00075
# 29      False  thumbcleanup_00076
#
#                                                 label  \
# 0                                         Finger Hand
# 1                                                Road
# 2               Human People Person Female Girl Woman
# 3                                                None
# 4                                                None
# 5           Flora Jar Plant Potted Plant Pottery Vase
# 6                            Bikini Clothing Swimwear
# 7   Knot Apartment Building Building City High Ris...
# 8                                 Human People Person
# 9                    Clothing Maillot Swimwear Bikini
# 10                                Human People Person
# 11                                Human People Person
# 12                               Cosmetics Aftershave
# 13                                               None
# 14                                    Chair Furniture
# 15  Guitar Guitarist Leisure Activities Music Musi...
# 16  Human People Person Blonde Female Girl Woman A...
# 17                                               None
# 18                                               None
# 19  Flora Jar Plant Potted Plant Pottery Vase Phot...
# 20                                 Blanket Home Decor
# 21                                               None
# 22                                Human People Person
# 23  Indoors Room Chair Furniture Dining Room Inter...
# 24              Human People Person Cosmetics Mascara
# 25                                               None
# 26                                               None
# 27                           Blonde Female Girl Woman
# 28                                               None
# 29                        Human People Person Reading
#
#                                                  text
# 0                                                None
# 1                                       .y ACE .y ACE
# 2                                                None
# 3                                                None
# 4   Aol. Log In wl our Aol a ount Aol. our wl In L...
# 5                                                 T T
# 6                                                None
# 7                                             H I H I
# 8                                               lt lt
# 9                                                None
# 10                                               None
# 11                                  19 Te LF 19 Te LF
# 12  MAYULO FIT me! +PORELESS MATTE B ESTEE LAUDER ...
# 13                                    anIrvEs anIrvEs
# 14  /Forrot ) bte lole INSII WVORI /Forrot ) bte l...
# 15                                    . . pO. . . pO.
# 16                                               None
# 17  SPIDER-MAN HomeceminG SPID Hom: synchrony MAN ...
# 18                                               None
# 19                                               None
# 20                                               None
# 21  ITAS Hour JIRS SEATOOD 0 ITAS Hour JIRS SEATOOD 0
# 22                                               None
# 23                                              AD AD
# 24                                               None
# 25                                               None
# 26                                               None
# 27                            GY Y TFLI S GY Y TFLI S
# 28                                               None
# 29                                          ACOR ACOR

# %%
media_new_df.to_csv("01_thumb_cleanup_text_data.csv")
